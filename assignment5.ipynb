# %% [markdown]
# [View in Colaboratory](https://colab.research.google.com/github/kaushik9728/ML-28th-May/blob/master/assignment5.ipynb)

# %%
import numpy as np

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('https://raw.githubusercontent.com/Shreyas3108/Weather/master/weather.csv')

# %%
df.head()
# Out:
#         Date  Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0  11/1/2007  Canberra      8.0     24.3       0.0          3.4       6.3
# 1  11/2/2007  Canberra     14.0     26.9       3.6          4.4       9.7
# 2  11/3/2007  Canberra     13.7     23.4       3.6          5.8       3.3
# 3  11/4/2007  Canberra     13.3     15.5      39.8          7.2       9.1
# 4  11/5/2007  Canberra      7.6     16.1       2.8          5.6      10.6
#
#   WindGustDir  WindGustSpeed WindDir9am      ...      Humidity3pm  \
# 0          NW           30.0         SW      ...               29
# 1         ENE           39.0          E      ...               36
# 2          NW           85.0          N      ...               69
# 3          NW           54.0        WNW      ...               56
# 4         SSE           50.0        SSE      ...               49
#
#    Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  \
# ...

# %%
df.hist(column='Evaporation',figsize=(10,15))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f31f4d9e410>]],
#       dtype=object)

# %%
df.boxplot(column='MaxTemp',figsize=(10,15))

# %%
hist_data=df['MaxTemp'].values

# %%
plt.hist(hist_data,10,normed=False,facecolor='green')
# Out:
# (array([10., 47., 50., 58., 53., 45., 34., 33., 15., 21.]),
#  array([ 7.6 , 10.42, 13.24, 16.06, 18.88, 21.7 , 24.52, 27.34, 30.16,
#         32.98, 35.8 ]),
#  <a list of 10 Patch objects>)

# %%
mintemp=df['MinTemp'].values

# %%
import seaborn as sns

# %%
maxtemp=df['MaxTemp'].values

# %%
sns.violinplot(df['Rainfall'], df['Evaporation'])
# Out:
# /usr/local/lib/python2.7/dist-packages/seaborn/categorical.py:588: FutureWarning: remove_na is deprecated and is a private function. Do not use.
#   kde_data = remove_na(group_data)
# /usr/local/lib/python2.7/dist-packages/seaborn/categorical.py:816: FutureWarning: remove_na is deprecated and is a private function. Do not use.
#   violin_data = remove_na(group_data)

# %%
sns.despine()

# %%
var = df.groupby(['WindGustSpeed','WindDir9am']).Rainfall.sum()

# %%
var.unstack().plot(kind='bar',stacked=True,  color=['red','blue','green','black'], grid=False)

# %%
df.hist(column='Cloud3pm',figsize=(10,15))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f31f1e88950>]],
#       dtype=object)

# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt

# %%
plt.style.use('seaborn-whitegrid')

# %%
fig = plt.figure()

# %%
ax = plt.axes()

# %%
x=df['Humidity3pm'].values

# %%
y=df['WindGustSpeed'].values

# %%
plt.plot(x,y);

# %%
plt.show()
